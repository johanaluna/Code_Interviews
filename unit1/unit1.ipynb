# %% [markdown]
# # Data Wrangling and Storytelling

# %% [markdown]
# Data Set : https://archive.ics.uci.edu/ml/datasets/Flags

# %% [markdown]
# # Data analysis:
# ## commands:
# - upload files :
#    * import pandas as pd
#    * pd.read_csv("flag.data", names=column_names)
#
#
# - replace values
#     * df['column'] = df['column'].replace({value_to_replace:'string', value2_to_replace:number})
#
#
# - df.head()
#
# - df.dtypes:
# float              float64 //
# int                  int64 //
# datetime    datetime64[ns] //
# string              object
#
# - df.shape
#
# - df.describe()
#   * Numeric: df.describe()
#   * Non-Numeric: df.describe(exclude='number')
#   * Both: df.describe(include='all')
#
#
# - Value_counts()
#     * df['column'].value_counts()
#
#
# - plot value_counts
#     * df['column'].value_counts().sort_index().plot();
#
#
# - null values are not nan
#     * import numpy as np
#     * df = df.replace({"?": np.NaN})
#
#
# - df.isnull().sum()
#
# - df.isna().sum()
#
# - df.fillna()
#
# - df.dropna()
#
# - df.drop()
#
# - Histogram
#     * df['column'].hist();
#
#
# - Density -- smooth hist
#     * df['COLUMN'].plot.density();
#
#
# - Plot 2 numeric columns
#     * df.plot.scatter('numeric_column1','numeric_column2');
#
#
# - Tab categorical features
#     * pd.crosstab(df['categorical_column1'],df['categorical_column2'])
#     * plot -->  pd.crosstab(df['categorical_column1'],df['categorical_column2']).plot();
#     * barras --> pd.crosstab(df['categorical_column1'],df['categorical_column2']).plot(kind='bar');
#     * horizontal bars--> pd.crosstab(df['categorical_column1'],df['categorical_column2']).plot(kind='barh');

# %% [markdown]
# - Display by default more tha 5 lines
#     * pd.set_option('display.max_rows',100)
#
#
# - Display by default more tha 5 columns
#     * pd.set_option('display.max_columns',100)
#
#
# - Select some columns from dataset
#     * df2 = df[['column1', 'columns2']].copy()
#
#
# - Check properties ?pd.read_csv()
#
#
# - drop columns
#     * df.drop(['url','member_id','desc','id'], axis=1)
#
#
# - Change type of a column
#     * df['column'].astype('int)
#
#
# - Apply function to a column
#     * df['column']=df['column'].apply(name_function)
#
#
# - Change numeric column to date
#     * df['earliest_cr_line']= pd.to_datetime(df['earliest_cr_line'], infer_datetime_format=True)
#
#
#
# - Concatenate
#     * https://chrisalbon.com/python/data_wrangling/pandas_join_merge_dataframe/
#
#
# - Sort by columns default = asc
#     * df = df.sort_values(by=['column1','column2'])
#
#
# - Replace values _ by nothing
#     * column.replace('_', '')
#
#
# - Replace more than 1 thing
#     * df.replace({"?": np.NaN, "_":""})

# %%
"""
Data: https://archive.ics.uci.edu/ml/machine-learning-databases/flags/flag.data
everything with ! is shell command
# !curl 'link' show me what is inside of the file 
# !wget 'link' download file 
# !head 'file' show the first 10 lines of the file
# !tail 'file' show the lastest lines of a file

"""
# Out:
# "\nData: https://archive.ics.uci.edu/ml/machine-learning-databases/flags/flag.data\n!curl 'link'\nshow me what is inside of the file \neverything with ! is shell command\n"

# %%
# !curl https://archive.ics.uci.edu/ml/machine-learning-databases/flags/flag.data
# Out:
# curl: (60) SSL certificate problem: certificate has expired
# More details here: https://curl.haxx.se/docs/sslcerts.html
#
# curl failed to verify the legitimacy of the server and therefore could not
# establish a secure connection to it. To learn more about this situation and
# how to fix it, please visit the web page mentioned above.

# %%
data="https://archive.ics.uci.edu/ml/machine-learning-databases/flags/flag.data"

# %%
# Upload data from URL
import pandas as pd

# %%
# df = pd.read_csv(data)

# %%
column_names=['name','landmass','zone','area','population','language','religion','bars','stripes','colours','red',
             'green','blue','gold','white','black','orange','mainhue','circles','crosses','saltires','quarters','sunstars',
             'crescent','triangle','icon','animate','text','topleft','botright']
len(column_names)
# Out:
# 30

# %%
df=pd.read_csv("flag.data", names=column_names)
df.shape
# Out:
# (194, 30)

# %%
df.head()
# Out:
#              name  landmass  zone  area  population  language  religion  bars  \
# 0     Afghanistan         5     1   648          16        10         2     0
# 1         Albania         3     1    29           3         6         6     0
# 2         Algeria         4     1  2388          20         8         2     2
# 3  American-Samoa         6     3     0           0         1         1     0
# 4         Andorra         3     1     0           0         6         0     3
#
#    stripes  colours  ...  saltires  quarters  sunstars  crescent  triangle  \
# 0        3        5  ...         0         0         1         0         0
# 1        0        3  ...         0         0         1         0         0
# 2        0        3  ...         0         0         1         1         0
# 3        0        5  ...         0         0         0         0         1
# 4        0        3  ...         0         0         0         0         0
#
#    icon  animate text  topleft  botright
# ...

# %%
#replace language number by names
df['language'] = df['language'].replace({1:'English', 2:'Spanish', 3:'French', 4:'German', 5:'Slavic', 6:'OtherIndo-European', 7:'Chinese', 8:'Arabic', 
               9:'Japanese/Turkish/Finnish/Magyar', 10:'Others'})

# %%
df['religion'] = df['religion'].replace({0:'Catholic', 1:'OtherChristian', 2:'Muslim', 3:'Buddhist', 4:'Hindu',
               5:'Ethnic', 6:'Marxist', 7:'Others'})

# %%
df.isnull().sum()
# Out:
# name          0
# landmass      0
# zone          0
# area          0
# population    0
# language      0
# religion      0
# bars          0
# stripes       0
# colours       0
# red           0
# green         0
# blue          0
# gold          0
# white         0
# black         0
# orange        0
# mainhue       0
# circles       0
# crosses       0
# saltires      0
# quarters      0
# sunstars      0
# crescent      0
# triangle      0
# icon          0
# animate       0
# text          0
# topleft       0
# botright      0
# dtype: int64

# %%
df.isna().sum()
# Out:
# name          0
# landmass      0
# zone          0
# area          0
# population    0
# language      0
# religion      0
# bars          0
# stripes       0
# colours       0
# red           0
# green         0
# blue          0
# gold          0
# white         0
# black         0
# orange        0
# mainhue       0
# circles       0
# crosses       0
# saltires      0
# quarters      0
# sunstars      0
# crescent      0
# triangle      0
# icon          0
# animate       0
# text          0
# topleft       0
# botright      0
# dtype: int64

# %%
# missing values in data are represented by ?

# %%
import numpy as np
df = df.replace({"?": np.NaN})

# %%
df.head(15)
# Out:
#                name  landmass  zone  area  population            language  \
# 0       Afghanistan         5     1   648          16              Others
# 1           Albania         3     1    29           3  OtherIndo-European
# 2           Algeria         4     1  2388          20              Arabic
# 3    American-Samoa         6     3     0           0             English
# 4           Andorra         3     1     0           0  OtherIndo-European
# 5            Angola         4     2  1247           7              Others
# 6          Anguilla         1     4     0           0             English
# 7   Antigua-Barbuda         1     4     0           0             English
# 8         Argentina         2     3  2777          28             Spanish
# 9         Argentine         2     3  2777          28             Spanish
# 10        Australia         6     2  7690          15             English
# 11          Austria         3     1    84           8              German
# ...

# %%
df.describe()
# Out:
#          landmass        zone          area   population        bars  \
# count  194.000000  194.000000    194.000000   194.000000  194.000000
# mean     3.572165    2.211340    700.046392    23.268041    0.453608
# std      1.553018    1.308274   2170.927932    91.934085    1.038339
# min      1.000000    1.000000      0.000000     0.000000    0.000000
# 25%      3.000000    1.000000      9.000000     0.000000    0.000000
# 50%      4.000000    2.000000    111.000000     4.000000    0.000000
# 75%      5.000000    4.000000    471.250000    14.000000    0.000000
# max      6.000000    4.000000  22402.000000  1008.000000    5.000000
#
#           stripes     colours         red       green        blue  ...  \
# count  194.000000  194.000000  194.000000  194.000000  194.000000  ...
# mean     1.551546    3.463918    0.788660    0.469072    0.510309  ...
# std      2.328005    1.300154    0.409315    0.500334    0.501187  ...
# ...

# %%
df.describe(exclude='number') #categorical columns
# Out:
#          name language        religion mainhue topleft botright
# count     194      194             194     194     194      194
# unique    194       10               8       8       7        8
# top     Tonga   Others  OtherChristian     red     red      red
# freq        1       46              60      71      56       69

# %%
df['religion'].value_counts()
# Out:
# OtherChristian    60
# Catholic          40
# Muslim            36
# Ethnic            27
# Marxist           15
# Buddhist           8
# Others             4
# Hindu              4
# Name: religion, dtype: int64

# %%
df['religion'].value_counts().sort_index().plot();

# %%
df['population'].hist();

# %%
df['zone'].hist(bins=16);

# %%
df.plot.scatter('area','population');

# %%
df['population'].plot.density();

# %%
df['population'].hist();

# %%
pd.crosstab(df['religion'],df['language'])
# Out:
# language        Arabic  Chinese  English  French  German  \
# religion
# Buddhist             0        3        0       0       0
# Catholic             0        0        1       5       3
# Ethnic               0        0        4       4       0
# Hindu                0        0        2       0       0
# Marxist              0        1        0       0       1
# Muslim              19        0        0       6       0
# OtherChristian       0        0       36       1       2
# Others               0        0        0       1       0
#
# language        Japanese/Turkish/Finnish/Magyar  OtherIndo-European  Others  \
# religion
# Buddhist                                      0                   0       5
# Catholic                                      0                   9       2
# Ethnic                                        0                   1      18
# Hindu                                         0                   1       1
# ...

# %%
pd.crosstab(df['religion'],df['language']).plot();

# %%
pd.crosstab(df['religion'],df['language']).plot(kind='bar');

# %%
pd.crosstab(df['religion'],df['language']).plot(kind='barh');

# %% [markdown]
# # New Data Example

# %%
import pandas as pd
data = "https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv"

# %%
df = pd.read_csv(data)
print(df.shape)
df.head()
# Out:
# (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
#                   ...
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# ...

# %%
#  display by default more tha 5 lines
# pd.set_option('display.max_rows',100)

# %%
df['LotFrontage'] # representing values as a float
# Out:
# 0        65.0
# 1        80.0
# 2        68.0
# 3        60.0
# 4        84.0
# 5        85.0
# 6        75.0
# 7         NaN
# 8        51.0
# 9        50.0
# 10       70.0
# 11       85.0
# 12        NaN
# 13       91.0
# 14        NaN
# 15       51.0
# 16        NaN
# 17       72.0
# 18       66.0
# 19       70.0
# 20      101.0
# 21       57.0
# 22       75.0
# 23       44.0
# 24        NaN
# 25      110.0
# 26       60.0
# 27       98.0
# 28       47.0
# 29       60.0
#         ...
# 1430     60.0
# 1431      NaN
# 1432     60.0
# 1433     93.0
# 1434     80.0
# 1435     80.0
# 1436     60.0
# 1437     96.0
# 1438     90.0
# 1439     80.0
# 1440     79.0
# 1441      NaN
# 1442     85.0
# 1443      NaN
# 1444     63.0
# 1445     70.0
# 1446      NaN
# 1447     80.0
# 1448     70.0
# 1449     21.0
# 1450     60.0
# 1451     78.0
# 1452     35.0
# 1453     90.0
# 1454     62.0
# 1455     62.0
# 1456     85.0
# 1457     66.0
# 1458     68.0
# 1459     75.0
# ...

# %%
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
#                  ...
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# ...

# %%
df['LotFrontage'].value_counts(dropna=False)
# Out:
# NaN      259
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
# 65.0      44
# 85.0      40
# 78.0      25
# 21.0      23
# 90.0      23
# 68.0      19
# 24.0      19
# 64.0      19
# 73.0      18
# 72.0      17
# 79.0      17
# 63.0      17
# 55.0      17
# 100.0     16
# 51.0      15
# 66.0      15
# 74.0      15
# 52.0      14
# 59.0      13
# 71.0      12
# 67.0      12
# 57.0      12
# 82.0      12
# 43.0      12
#         ...
# 129.0      2
# 313.0      2
# 118.0      2
# 122.0      2
# 121.0      2
# 101.0      2
# 109.0      2
# 115.0      2
# 116.0      2
# 114.0      2
# 153.0      1
# 149.0      1
# 150.0      1
# 111.0      1
# 182.0      1
# 46.0       1
# 112.0      1
# 141.0      1
# 33.0       1
# 152.0      1
# 160.0      1
# 168.0      1
# 128.0      1
# 144.0      1
# 39.0       1
# 106.0      1
# 38.0       1
# 138.0      1
# 140.0      1
# 137.0      1
# Name: LotFrontage, Length: 111, dtype: int64

# %%
type(df['LotFrontage'])
# Out:
# pandas.core.series.Series

# %%
df2= df[['TotalBsmtSF','1stFlrSF','2ndFlrSF','SalePrice']].copy()

# %%
df2.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice
# 0          856       856       854     208500
# 1         1262      1262         0     181500
# 2          920       920       866     223500
# 3          756       961       756     140000
# 4         1145      1145      1053     250000

# %%
df2['TotalSF'] = df2['TotalBsmtSF'] + df2['1stFlrSF'] + df2['2ndFlrSF']

# %%
df2.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSF
# 0          856       856       854     208500     2566
# 1         1262      1262         0     181500     2524
# 2          920       920       866     223500     2706
# 3          756       961       756     140000     2473
# 4         1145      1145      1053     250000     3343

# %%
df2['PricePerSqFt'] = df2['SalePrice'] / df2['TotalSF']

# %%
df2.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSF  PricePerSqFt
# 0          856       856       854     208500     2566     81.254871
# 1         1262      1262         0     181500     2524     71.909667
# 2          920       920       866     223500     2706     82.594235
# 3          756       961       756     140000     2473     56.611403
# 4         1145      1145      1053     250000     3343     74.783129

# %%
file ="LoanStats_2018Q4.csv"
df = pd.read_csv(file,skiprows=1, skipfooter=2, engine='python')
print(df.shape)
df.head()
# Out:
# (128412, 144)
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      35000        35000          35000.0   36 months
# 1 NaN        NaN       5000         5000           5000.0   36 months
# 2 NaN        NaN      10000        10000          10000.0   60 months
# 3 NaN        NaN      17100        17100          17100.0   36 months
# 4 NaN        NaN       4000         4000           4000.0   36 months
#
#   int_rate  installment grade sub_grade  ...  \
# 0   14.47%      1204.23     C        C2  ...
# 1   22.35%       191.86     D        D5  ...
# 2   23.40%       284.21     E        E1  ...
# 3   18.94%       626.30     D        D2  ...
# 4   10.72%       130.43     B        B2  ...
#
#   orig_projected_additional_accrued_interest hardship_payoff_balance_amount  \
# 0                                        NaN                            NaN
# 1                                        NaN                            NaN
# ...

# %%
# ?pd.read_csv()

# %%
df.isnull().sum().sort_values()
# Out:
# inq_fi                                             0
# delinq_amnt                                        0
# chargeoff_within_12_mths                           0
# acc_open_past_24mths                               0
# inq_last_12m                                       0
# total_cu_tl                                        0
# total_rev_hi_lim                                   0
# max_bal_bc                                         0
# open_rv_24m                                        0
# open_rv_12m                                        0
# total_bal_il                                       0
# open_il_24m                                        0
# hardship_flag                                      0
# open_act_il                                        0
# open_acc_6m                                        0
# tot_cur_bal                                        0
# tot_coll_amt                                       0
# acc_now_delinq                                     0
# ...

# %%
df.tail()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 128407 NaN        NaN      23000        23000          23000.0   36 months
# 128408 NaN        NaN      10000        10000          10000.0   36 months
# 128409 NaN        NaN       5000         5000           5000.0   36 months
# 128410 NaN        NaN      10000        10000           9750.0   36 months
# 128411 NaN        NaN      10000        10000          10000.0   36 months
#
#        int_rate  installment grade sub_grade  ...  \
# 128407   15.02%       797.53     C        C3  ...
# 128408   15.02%       346.76     C        C3  ...
# 128409   13.56%       169.83     C        C1  ...
# 128410   11.06%       327.68     B        B3  ...
# 128411   16.91%       356.08     C        C5  ...
#
#        orig_projected_additional_accrued_interest  \
# 128407                                        NaN
# 128408                                        NaN
# 128409                                        NaN
# ...

# %%
# the shape of my data is (128412, 144)
# columns like:
# url                                           128412
# member_id                                     128412
# desc                                          128412
# id                                            128412
# have all they rows empty

# %%
df = df.drop(['url','member_id','desc','id'], axis=1).copy()

# %%
df['term'].value_counts()
# Out:
#  36 months    88179
#  60 months    40233
# Name: term, dtype: int64

# %%
# clean int_rate column

# %%
df['int_rate'].head()
# Out:
# 0     14.47%
# 1     22.35%
# 2     23.40%
# 3     18.94%
# 4     10.72%
# Name: int_rate, dtype: object

# %%
#this column is a string and also has a space before the numbers
df['int_rate'][0]
# Out:
# ' 14.47%'

# %%
rate = ' 14.47%'

# %%
# strip() remove space beggining or at the end of my string
# strip('%') remove percentage
float(rate.strip().strip('%'))
# Out:
# 14.47

# %%
# create a function
def int_rate_to_float(value):
    return float(value.strip().strip('%'))

# %%
int_rate_to_float(rate)
# Out:
# 14.47

# %%
df['int_rate']=df['int_rate'].apply(int_rate_to_float)
df['int_rate'].head()
# Out:
# 0    14.47
# 1    22.35
# 2    23.40
# 3    18.94
# 4    10.72
# Name: int_rate, dtype: float64

# %%
df['emp_title'].value_counts()
# Out:
# Unknown                                    20947
# Teacher                                     2557
# Manager                                     2395
# Registered Nurse                            1418
# Driver                                      1258
# Supervisor                                  1160
# Truck Driver                                 920
# Rn                                           834
# Office Manager                               805
# Sales                                        803
# General Manager                              791
# Project Manager                              720
# Owner                                        625
# Director                                     523
# Operations Manager                           518
# Sales Manager                                500
# Police Officer                               440
# Nurse                                        425
# Technician                                   420
# ...

# %%
import numpy as np
examples_titles = ['Staff Physician',' Tax Consultant',np.nan]

# %%
def clean_titles(title):
    if isinstance(title,str):
        return title.strip().title()
    else:
        return "Unknown"

# %%
df['emp_title'] = df['emp_title'].apply(clean_titles)

# %%
# DATES
df['issue_d']
# Out:
# 0         Dec-2018
# 1         Dec-2018
# 2         Dec-2018
# 3         Dec-2018
# 4         Dec-2018
# 5         Dec-2018
# 6         Dec-2018
# 7         Dec-2018
# 8         Dec-2018
# 9         Dec-2018
# 10        Dec-2018
# 11        Dec-2018
# 12        Dec-2018
# 13        Dec-2018
# 14        Dec-2018
# 15        Dec-2018
# 16        Dec-2018
# 17        Dec-2018
# 18        Dec-2018
# 19        Dec-2018
# 20        Dec-2018
# 21        Dec-2018
# 22        Dec-2018
# 23        Dec-2018
# 24        Dec-2018
# 25        Dec-2018
# 26        Dec-2018
# 27        Dec-2018
# 28        Dec-2018
# 29        Dec-2018
#             ...
# 128382    Oct-2018
# 128383    Oct-2018
# 128384    Oct-2018
# 128385    Oct-2018
# 128386    Oct-2018
# 128387    Oct-2018
# 128388    Oct-2018
# 128389    Oct-2018
# 128390    Oct-2018
# 128391    Oct-2018
# 128392    Oct-2018
# 128393    Oct-2018
# 128394    Oct-2018
# 128395    Oct-2018
# 128396    Oct-2018
# 128397    Oct-2018
# ...

# %%
df['issue_d'] = pd.to_datetime(df['issue_d'], infer_datetime_format=True)

# %%
df['issue_d']
# Out:
# 0        2018-12-01
# 1        2018-12-01
# 2        2018-12-01
# 3        2018-12-01
# 4        2018-12-01
# 5        2018-12-01
# 6        2018-12-01
# 7        2018-12-01
# 8        2018-12-01
# 9        2018-12-01
# 10       2018-12-01
# 11       2018-12-01
# 12       2018-12-01
# 13       2018-12-01
# 14       2018-12-01
# 15       2018-12-01
# 16       2018-12-01
# 17       2018-12-01
# 18       2018-12-01
# 19       2018-12-01
# 20       2018-12-01
# 21       2018-12-01
# 22       2018-12-01
# 23       2018-12-01
# 24       2018-12-01
# 25       2018-12-01
# 26       2018-12-01
# 27       2018-12-01
# 28       2018-12-01
# 29       2018-12-01
#             ...
# 128382   2018-10-01
# 128383   2018-10-01
# 128384   2018-10-01
# 128385   2018-10-01
# 128386   2018-10-01
# 128387   2018-10-01
# 128388   2018-10-01
# 128389   2018-10-01
# 128390   2018-10-01
# 128391   2018-10-01
# 128392   2018-10-01
# 128393   2018-10-01
# 128394   2018-10-01
# 128395   2018-10-01
# ...

# %%
df['issue_d'].value_counts()
# Out:
# 2018-10-01    46305
# 2018-11-01    41973
# 2018-12-01    40134
# Name: issue_d, dtype: int64

# %%
df['issue_d'][0]
# Out:
# Timestamp('2018-12-01 00:00:00')

# %%
df['earliest_cr_line']= pd.to_datetime(df['earliest_cr_line'], infer_datetime_format=True)

# %%
df['earliest_cr_line'] = (df['issue_d'] - df['earliest_cr_line']).dt.days / 365

# %%
df['earliest_cr_line'].describe()
# Out:
# count    128412.000000
# mean         16.054497
# std           7.908317
# min           3.084932
# 25%          11.093151
# 50%          14.427397
# 75%          19.846575
# max          68.961644
# Name: earliest_cr_line, dtype: float64

# %% [markdown]
# # Graphs

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator, MultipleLocator, FuncFormatter

np.random.seed(19680801)

X = np.linspace(0.5, 3.5, 100)
Y1 = 3+np.cos(X)
Y2 = 1+np.cos(1+X/0.75)/2
Y3 = np.random.uniform(Y1, Y2, len(X))

fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(1, 1, 1, aspect=1)


def minor_tick(x, pos):
    if not x % 1.0:
        return ""
    return "%.2f" % x

ax.xaxis.set_major_locator(MultipleLocator(1.000))
ax.xaxis.set_minor_locator(AutoMinorLocator(4))
ax.yaxis.set_major_locator(MultipleLocator(1.000))
ax.yaxis.set_minor_locator(AutoMinorLocator(4))
ax.xaxis.set_minor_formatter(FuncFormatter(minor_tick))

ax.set_xlim(0, 4)
ax.set_ylim(0, 4)

ax.tick_params(which='major', width=1.0)
ax.tick_params(which='major', length=10)
ax.tick_params(which='minor', width=1.0, labelsize=10)
ax.tick_params(which='minor', length=5, labelsize=10, labelcolor='0.25')

ax.grid(linestyle="--", linewidth=0.5, color='.25', zorder=-10)

ax.plot(X, Y1, c=(0.25, 0.25, 1.00), lw=2, label="Blue signal", zorder=10)
ax.plot(X, Y2, c=(1.00, 0.25, 0.25), lw=2, label="Red signal")
ax.plot(X, Y3, linewidth=0,
        marker='o', markerfacecolor='w', markeredgecolor='k')

ax.set_title("Anatomy of a figure", fontsize=20, verticalalignment='bottom')
ax.set_xlabel("X axis label")
ax.set_ylabel("Y axis label")

ax.legend()


def circle(x, y, radius=0.15):
    from matplotlib.patches import Circle
    from matplotlib.patheffects import withStroke
    circle = Circle((x, y), radius, clip_on=False, zorder=10, linewidth=1,
                    edgecolor='black', facecolor=(0, 0, 0, .0125),
                    path_effects=[withStroke(linewidth=5, foreground='w')])
    ax.add_artist(circle)


def text(x, y, text):
    ax.text(x, y, text, backgroundcolor="white",
            ha='center', va='top', weight='bold', color='blue')

### Minor tick
circle(0.50, -0.10)
text(0.50, -0.32, "Minor tick label")

### Major tick
circle(-0.03, 4.00)
text(0.03, 3.80, "Major tick")

### Minor tick
circle(0.00, 3.50)
text(0.00, 3.30, "Minor tick")

### Major tick label
circle(-0.15, 3.00)
text(-0.15, 2.80, "Major tick label")

### X Label
circle(1.80, -0.27)
text(1.80, -0.45, "X axis label")

### Y Label
circle(-0.27, 1.80)
text(-0.27, 1.6, "Y axis label")

### Title
circle(1.60, 4.13)
text(1.60, 3.93, "Title")

### Blue plot
circle(1.75, 2.80)
text(1.75, 2.60, "Line\n(line plot)")

### Red plot
circle(1.20, 0.60)
text(1.20, 0.40, "Line\n(line plot)")

### Scatter plot
circle(3.20, 1.75)
text(3.20, 1.55, "Markers\n(scatter plot)")

### Grid
circle(3.00, 3.00)
text(3.00, 2.80, "Grid")

### Legend
circle(3.70, 3.80)
text(3.70, 3.60, "Legend")

### Axes
circle(0.5, 0.5)
text(0.5, 0.3, "Axes")

### Figure
circle(-0.3, 0.65)
text(-0.3, 0.45, "Figure")

color = 'blue'
ax.annotate('Spines', xy=(4.0, 0.35), xytext=(3.3, 0.5),
            weight='bold', color=color,
            arrowprops=dict(arrowstyle='->',
                            connectionstyle="arc3",
                            color=color))

ax.annotate('', xy=(3.15, 0.0), xytext=(3.45, 0.45),
            weight='bold', color=color,
            arrowprops=dict(arrowstyle='->',
                            connectionstyle="arc3",
                            color=color))

ax.text(4.0, -0.4, "Made with http://matplotlib.org",
        fontsize=10, ha="right", color='.5')

plt.show();

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

fake = pd.Series([38, 3, 2, 1, 2, 4, 6, 5, 5, 33], 
                 index=range(1,11))

fake.plot.bar(color='C1', width=0.9);

### Set stylesheet
plt.style.use('fivethirtyeight')

### figure axes syntax
fig, ax = plt.subplots()

### Make the figure background color white
fig.patch.set(facecolor='white')

### put bars on the axes
fake.plot.bar(width=0.9, color='#ED713A')

### Set axes background color
ax.set(facecolor='white')

### Set plot title
ax.set_title("'An Inconvenient Sequel: truth To Power' is divisive", fontsize=12, fontweight='bold', x=.35, y=1.1) 

### Set plot ylabel
ax.set_ylabel('Percent of total votes', fontsize=9, fontweight='bold')

### Set plot xlabel
ax.set_xlabel('Rating', fontsize=9, fontweight='bold')

### Set subtitle
ax.text(s='IMDb ratings for the film as of Aug. 29', y=41.5, x=-1.8, fontsize=12)

### set y axis labels, tick marks and grid lines
ax.set_yticklabels(['0', '10', '20', '30', '40%'], fontsize=10)
ax.set_yticks(range(0,50,10))

### Set x axis labels, tick marks and grid lines
ax.set_xticklabels(range(1,11,1), rotation='horizontal', fontsize=10)

### Show the plot and squelch the funny output
fig.show();

# %%
df = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/inconvenient-sequel/ratings.csv')
df.head()
# Out:
#                     timestamp  respondents        category  \
# 0  2017-07-17 12:28:32.785639          402           Males
# 1  2017-07-17 12:28:33.025600           78         Females
# 2  2017-07-17 12:28:33.273919            4   Aged under 18
# 3  2017-07-17 12:28:33.495325            4  Males under 18
# 4  2017-07-17 12:28:33.722849          130      Aged 18-29
#
#                                                 link  average  mean  median  \
# 0   http://www.imdb.com/title/tt6322922/ratings-male      4.6   5.0       2
# 1  http://www.imdb.com/title/tt6322922/ratings-fe...      6.9   7.7      10
# 2  http://www.imdb.com/title/tt6322922/ratings-age_1      4.2   4.2       3
# 3  http://www.imdb.com/title/tt6322922/ratings-ma...      4.2   4.2       3
# 4  http://www.imdb.com/title/tt6322922/ratings-age_2      6.3   6.5       9
#
#    1_votes  2_votes  3_votes  ...  1_pct  2_pct  3_pct  4_pct  5_pct  6_pct  \
# ...

# %%
df.tail()
# Out:
#                         timestamp  respondents         category  \
# 80048  2017-08-29 23:10:05.369510            8       IMDb staff
# 80049  2017-08-29 23:10:05.598331           41  Top 1000 voters
# 80050  2017-08-29 23:10:05.794141          925         US users
# 80051  2017-08-29 23:10:06.022268          565     Non-US users
# 80052  2017-08-29 23:10:06.218251         2662       IMDb users
#
#                                                     link  average  mean  \
# 80048  http://www.imdb.com/title/tt6322922/ratings-im...      8.4   7.2
# 80049  http://www.imdb.com/title/tt6322922/ratings-to...      4.6   4.7
# 80050    http://www.imdb.com/title/tt6322922/ratings-usa      4.8   5.0
# 80051  http://www.imdb.com/title/tt6322922/ratings-in...      6.4   6.5
# 80052        http://www.imdb.com/title/tt6322922/ratings      5.4   5.6
#
#        median  1_votes  2_votes  3_votes  ...  1_pct  2_pct  3_pct  4_pct  \
# ...

# %%
### Convert timestamps strings to actual datetime objects
df['timestamp'] = pd.to_datetime(df['timestamp'])

### Use the timestamp as the unique index identifier 
### so that we can select rows by timestamp
df.set_index('timestamp', inplace=True)

### grab only the rows corresponding to the last day
lastday = df['2017-08-29']

### get the demographic breakdowns for all IMDb users on the last day
lastday_filtered = lastday[lastday['category'] == 'IMDb users']
lastday_filtered.tail()

### just grab the very last line (latest timestamp) of IMDb user ratings
### this should be the most up to date data from the dataset
final = lastday_filtered.tail(1)
final.T

### Grab only the percentage columns since we don't care about the raw 
### counts in making our graph
pct_columns = ['1_pct', '2_pct', '3_pct', '4_pct', '5_pct',
               '6_pct', '7_pct', '8_pct', '9_pct', '10_pct']
final[pct_columns].T
# Out:
# timestamp  2017-08-29 23:10:06.218251
# 1_pct                            38.4
# 2_pct                             2.6
# 3_pct                             1.4
# 4_pct                             0.9
# 5_pct                             2.1
# 6_pct                             4.1
# 7_pct                             5.8
# 8_pct                             5.5
# 9_pct                             5.5
# 10_pct                           33.7

# %%
### Reset the index so that it's numeric again
### and rename the percent column for easy access in our plotting
plot_data = final[pct_columns].T
plot_data.index = range(1,11)
plot_data.columns = ['percent']
plot_data
# Out:
#     percent
# 1      38.4
# 2       2.6
# 3       1.4
# 4       0.9
# 5       2.1
# 6       4.1
# 7       5.8
# 8       5.5
# 9       5.5
# 10     33.7

# %%
import matplotlib.pyplot as plt

### Set stylesheet
plt.style.use('fivethirtyeight')

### figure axes syntax
fig, ax = plt.subplots()

### Make the figure background color white
fig.patch.set(facecolor='white')

### put bars on the axes
ax.bar(x=range(1,11), height=plot_data['percent'], width=0.9, color='#ED713A')

### Set axes background color
ax.set(facecolor='white')

### Set plot title
ax.set_title("'An Inconvenient Sequel: truth To Power' is divisive", fontsize=12, fontweight='bold', x=.35, y=1.1) 

### Set plot ylabel
ax.set_ylabel('Percent of total votes', fontsize=9, fontweight='bold')

### Set plot xlabel
ax.set_xlabel('Rating', fontsize=9, fontweight='bold')

### Set subtitle
ax.text(s='IMDb ratings for the film as of Aug. 29', y=42.5, x=-1, fontsize=12)

### set y axis labels, tick marks and grid lines
ax.set_yticklabels(['0', '10', '20', '30', '40%'], fontsize=10)
ax.set_yticks(range(0,50,10))

### Set x axis labels, tick marks and grid lines
ax.set_xticklabels(range(1,11,1), rotation='horizontal', fontsize=10, fontweight=550)
ax.set_xticks(range(1,11))

### Show the plot and squelch the funny output
fig.show()
